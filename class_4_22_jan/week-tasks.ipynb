# %% [markdown]
# # Дополнительные темы

# %% [markdown]
# ## Ловля исключений — try и except
#
# Если в коде происходит ошибка, но мы не хотим завершать программу:

# %%
i = input()
i = int(i)


print('Some other functionality...')
# Out:
#  abc
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
#     at line 2 in <module>
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
i = input()
try:
    i = int(i)
except:
    print("i should be integer!")

print('Some other functionality...')
# Out:
#  abc
# i should be integer!
# Some other functionality...

# %% [markdown]
# **Не делайте так, как в коде выше - указывайте конкретное исключение!**

# %%
i = input()
try:
    i = int(i)
except ValueError:
    print("i should be integer!")
# Out:
#  abc
# i should be integer!

# %% [markdown]
# Информацию из самого исключения можно использовать:

# %%
i = input()
try:
    i = int(i)
except ValueError as some_var:
    print('TO LOGS:', type(some_var))
    print("i should be integer!")
    print('TO LOGS:', some_var)

print('Continue...')
# Out:
#  abc
# TO LOGS: <class 'ValueError'>
# i should be integer!
# TO LOGS: invalid literal for int() with base 10: 'abc'
# Continue...

# %% [markdown]
# Аналог else:

# %%
try:
    k = 1 / 0
except ZeroDivisionError:
    k = -1
finally:
    print('Этот блок выполяется в любом случае')
    print(k)
# Out:
# Этот блок выполяется в любом случае
# -1

# %% [markdown]
# Порядок имеет значение!

# %%
try:
    k = 1 / 0
except ZeroDivisionError:
    k = -1
except ArithmeticError:
    k = 0
finally:
    print('Этот блок выполяется всегда')
    print(k)
# Out:
# Этот блок выполяется всегда
# -1

# %%
try:
    k = 1 / 0
except ArithmeticError:
    k = 0
except ZeroDivisionError:
    k = -1
finally:
    print('Этот блок выполяется всегда')
    print(k)
# Out:
# Этот блок выполяется всегда
# 0

# %%
from IPython.display import Image
Image('exceptions.png')

# %%
i = input()

try:
    i = int(i)
except:
    try:
        i = float(i)
    except:
        print('i is not integer or float!!!')

print(i)
print(type(i))
# Out:
#  abc
# i is not integer or float!!!
# abc
# <class 'str'>

# %%
i = input()

try:
    i = int(i)
except:
    try:
        i = float(i)
    except:
        print('i is not integer or float!!!')

print(i)
print(type(i))
# Out:
#  2.5
# 2.5
# <class 'float'>

# %%
i = input()

try:
    i = int(i)
except:
    try:
        i = float(i)
    except:
        print('i is not integer or float!!!')

print(i)
print(type(i))
# Out:
#  1
# 1
# <class 'int'>

# %% [markdown]
# ## Операции с float
#
# Что выведет следующий код?

# %%
0.1 + 0.2 == 0.3
# Out:
# False

# %%
0.5 + 1.75 == 2.25
# Out:
# True

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %% [markdown]
# **Почему так происходит? Вспомните лекции CS50!**

# %% [markdown]
# Дело в том, что Python под капотом переводит все числа в двоичную систему, и это происходит не со 100процентной точностью. Упражнение на гугление: как считать точно?

# %%
from decimal import Decimal, getcontext

getcontext().prec = 100

a = Decimal('0.1')
b = Decimal('0.2')

# %%
float(a + b) == 0.3
# Out:
# True

# %% [markdown]
# ## Красивый вывод с f-strings

# %%
name = 'Tim'
age = 18

message = f'My name is {name} and I am {age} years old'
print(message)
# Out:
# My name is Tim and I am 18 years old

# %% [markdown]
# Прямо внутри f-strings можно что-то делать:

# %%
year_days = 365
print(f'I am {year_days * age} days old!')
# Out:
# I am 6570 days old!

# %%
V = 3.1415926

print(f'Pi is: {pi:.2f}')
# Out:
# Pi is: 3.14

# %%
pi
# Out:
# 3.1415926

# %%
ratio = 1 / pi

print(f'Ratio is: {ratio:.2%}')
# Out:
# Ratio is: 31.83%

# %% [markdown]
# Подробнее об f-strings можно почитать [по ссылке](https://realpython.com/python-f-strings/) и [по другой ссылке](https://miguendes.me/73-examples-to-help-you-master-pythons-f-strings).

# %% [markdown]
# # Разбор задач по результатам недели

# %% [markdown]
# ## ЗАДАЧА 1
#
# В то далёкое время, когда Паша ходил в школу, ему очень не нравилась формула Герона для вычисления площади треугольника, так как казалась слишком сложной. В один прекрасный момент Павел решил избавить всех школьников от страданий и написать и распространить по школам программу, вычисляющую площадь треугольника по трём сторонам.
#
# Одна проблема: так как эта формула не нравилась Павлу, он её не запомнил. Помогите ему завершить доброе дело и напишите программу, вычисляющую площадь треугольника по переданным длинам трёх его сторон по формуле Герона:
#
# $S=\sqrt{p(p−a)(p−b)(p−c)}$
# ​
#
# где $p=\dfrac{a+b+c}{2}$ – полупериметр треугольника. На вход программе подаются целые числа, выводом программы должно являться вещественное число, соответствующее площади треугольника.

# %%
a = int(input())
b = int(input())
c = int(input())
p = (a + b + c) / 2
S = (p * (p-a) * (p-b) * (p-c)) ** 0.5
print(S)
# Out:
#  3
#  4
#  5
# 6.0

# %%
a, b, c = int(input()), int(input()), int(input())

p = (a + b + c) / 2
S = (p * (p-a) * (p-b) * (p-c)) ** 0.5

print(S)

# %%
[1, 2] + [3]
# Out:
# [1, 2, 3]

# %%
a, b, c = [int(input()) for i in range(2)] + [float(int(input()))]

p = (a + b + c) / 2
S = (p * (p-a) * (p-b) * (p-c)) ** 0.5

print(S)
# Out:
#  3
#  4
#  5
# 6.0

# %% [markdown]
# ## ЗАДАЧА 2
#
# Напишите программу, принимающую на вход целое число, которая выводит True, если переданное значение попадает в интервал $(-15, 12] \cup (14, 17) \cup [19, +\infty)(−15,12]∪(14,17)∪[19,+∞)$ и False в противном случае (регистр символов имеет значение).

# %%
print(1 < 2)
# Out:
# True

# %%
n = int(input())
print(-15 < n <= 12 or 14 < n < 17 or 19 <= n)
# Нам не нужны if!
# Out:
#  10
# True

# %%
n = int(input())
print(all([-15 < n <= 12, 14 < n < 17, 19 <= n]))
# Out:
#  -20
# False

# %% [markdown]
# ## ЗАДАЧА 3
#
# Напишите простой калькулятор, который считывает с пользовательского ввода три строки: первое число, второе число и операцию, после чего применяет операцию к введённым числам ("первое число" "операция" "второе число") и выводит результат на экран.
#
# Поддерживаемые операции: +, -, /, *, mod, pow, div, где
# mod — это взятие остатка от деления,
# pow — возведение в степень,
# div — целочисленное деление.
#
# Если выполняется деление и второе число равно 0, необходимо выводить строку "Деление на 0!".
#
# Обратите внимание, что на вход программе приходят вещественные числа.

# %%
a = float(input())
b = float(input())
op = input()

if b == 0 and (op == "mod" or op == "/" or op == "div"):
    print("Деление на 0!")
elif op == '+':
    print(a + b)
elif op == '-':
    print(a - b)
elif op == '*':
    print(a * b)
elif op == '/':
    print(a / b)
elif op == 'mod':
    print(a % b)
elif op == 'pow':
    print(a ** b)
elif op == 'div':
    print(a // b)
else:
    print("Unknown operator")

# %%
1 + 2
# Out:
# 3

# %%
eval('1 + 2')
# Out:
# 3

# %%
a, b, act = input(), input(), input()

try:
    print(eval('('+a+')' + {'mod': '%', 'div': '//', 'pow': '**'}.get(act, act) + b))
except ZeroDivisionError:
    print('Деление на 0!')

# %% [markdown]
# ## ЗАДАЧА 4
#
# Жители страны Малевии часто экспериментируют с планировкой комнат. Комнаты бывают треугольные, прямоугольные и круглые. Чтобы быстро вычислять жилплощадь, требуется написать программу, на вход которой подаётся тип фигуры комнаты и соответствующие параметры, которая бы выводила площадь получившейся комнаты.
# Для числа π в стране Малевии используют значение 3.14.
#
# Формат ввода, который используют Малевийцы:
#
# ```
# треугольник
# a
# b
# c
# где a, b и c — длины сторон треугольника
# ```
#
# ```
# прямоугольник
# a
# b
# где a и b — длины сторон прямоугольника
# ```
#
# ```
# круг
# r
# где r — радиус окружности
# ```

# %%
type = input()

a = int(input())
if type == 'круг':
    print(a**2 * 3.14)
elif type == 'прямоугольник':
    b = int(input())
    print(a * b)
else:
    b = int(input())
    c = int(input())
    p = (a + b + c) / 2
    print((p * (p - a) * (p - b) * (p - c)) ** 0.5)

# %% [markdown]
# ## ЗАДАЧА 5
#
# Напишите программу, которая получает на вход три целых числа, по одному числу в строке, и выводит на консоль в три строки сначала максимальное, потом минимальное, после чего оставшееся число.
#
# На ввод могут подаваться и повторяющиеся числа.

# %%
a, b, c = int(input()), int(input()), int(input())

if a < b:
	a, b = b, a
if a < c:
	a, c = c, a
if b > c:
	b, c = c, b

print(a, b, c, sep='\n')

# %%
a, b, c = int(input()), int(input()), int(input())

if a < b:
	a, b = b, a
if a < c:
	a, c = c, a
if b > c:
	b, c = c, b
print(a)
print(b)
print(c)

# %%
a, b, c = int(input()), int(input()), int(input())

if b > a:
    maxim = b
    minim = a
else:
    maxim = a
    minim = b


if c > maxim:
    maxim = c
if c < minim:
    minim = c

ost = a + b + c - minim - maxim

print(maxim)
print(minim)
print(ost)

# %%
l = sorted([int(input()), int(input()), int(input())])
print(*(l[2], l[0], l[1]), sep = '\n')

# %% [markdown]
# ## ЗАДАЧА 6
#
# В институте биоинформатики по офису передвигается робот. Недавно студенты из группы программистов написали для него программу, по которой робот, когда заходит в комнату, считает количество программистов в ней и произносит его вслух: "n программистов".
#
# Для того, чтобы это звучало правильно, для каждого nn нужно использовать верное окончание слова.
#
# Напишите программу, считывающую с пользовательского ввода целое число nn (неотрицательное), выводящее это число в консоль вместе с правильным образом изменённым словом "программист", для того, чтобы робот мог нормально общаться с людьми, например: 1 программист, 2 программиста, 5 программистов.
#
# В комнате может быть очень много программистов. Проверьте, что ваша программа правильно обработает все случаи, как минимум до 1000 человек.
#
# Дополнительный комментарий к условию:
#
# Обратите внимание, что задача не так проста, как кажется на первый взгляд. Если ваше решение не проходит какой-то тест, это значит, что вы не рассмотрели какой-то из случаев входных данных (число программистов $0 \le n \le 10000≤n≤1000$). Обязательно проверяйте свои решения на дополнительных значениях, а не только на тех, что приведены в условии задания.
#
# Так как задание повышенной сложности, вручную код решений проверяться не будет. Если вы столкнулись с ошибкой в первых четырёх тестах, проверьте, что вы используете только русские символы для ответа. В остальных случаях ищите ошибку в логике работы программы.

# %%
from IPython.display import Image
Image('BIO.JPG')

# %%
n = int(input())

if n % 10 in (2, 3, 4):
    word = 'программиста'
elif n % 10 == 1:
    word = 'программист'
else:
    word = 'программистов'
    
if n % 100 in (11, 12, 13, 14):
    word = 'программистов'
    
print(n, word)

# %% [markdown]
# ## ЗАДАЧА 7 (ДОПОЛНИТЕЛЬНАЯ)
#
# Паша очень любит кататься на общественном транспорте, а получая билет, сразу проверяет, счастливый ли ему попался. Билет считается счастливым, если сумма первых трех цифр совпадает с суммой последних трех цифр номера билета.
#
# Однако Паша очень плохо считает в уме, поэтому попросил вас написать программу, которая проверит равенство сумм и выведет "Счастливый", если суммы совпадают, и "Обычный", если суммы различны.
#
# На вход программе подаётся строка из шести цифр.
#
# Выводить нужно только слово "Счастливый" или "Обычный", с большой буквы.

# %%
a, b, c, d, e, f = map(int, input())
print('Счастливый' if a + b + c == d + e + f else 'Обычный')

# %%
num_list = list(map(int, input().split(' ')))
# Out:
#  1 25 13

# %%
num_list
# Out:
# [1, 25, 13]

# %% [markdown]
# # Проект
#
# Варианты программы:
# - Для рассчета BMI
# - Для рассчета калорий
# - Для рассчёта прибыльности вклада или трат на кредит (с учётом сложного процента)
# - Любая простая консольная программа для упрощения вашей жизни
#
# Требования:
# - Постарайтесь думать о потенциальном пользователе
# - Обрабатывайте любые возможные выходные данные, проверяйте их
# - Пишите хороший код
#     - Названия переменных (ответ на вопрос ЧТО)
#     - Комментарии (ответ на вопрос ПОЧЕМУ/ЗАЧЕМ)
#     - Лаконичность
#     - Читабельность (посмотрите на код со стороны)
